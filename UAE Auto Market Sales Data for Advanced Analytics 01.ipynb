# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Data Import

# %%
db = pd.read_csv('dubizzle_cars_dataset.csv')

# %%
#Backup
db2 = pd.read_csv('dubizzle_cars_dataset.csv')

# %%
db.head(5)
# Out:
#     price       brand      model           trim  kilometers  year  \
# 0  129900       Dodge        Ram  1500 SLT Crew       47566  2021
# 1  319900  Alfa Romeo    Stelvio   Quadrifoglio        8914  2020
# 2  149900        Audi         Q5         S-line       72205  2019
# 3   79900  Alfa Romeo  GIULIETTA         Veloce       49193  2021
# 4  154900         GAC        GS8             GL          30  2024
#
#    vehicle_age_years regional_specs  doors      body_type  ... interior_color  \
# 0                  3      GCC Specs      4  Pick Up Truck  ...        Unknown
# 1                  4      GCC Specs      5            SUV  ...          Black
# 2                  5      GCC Specs      5            SUV  ...          Brown
# 3                  3      GCC Specs      4      Hatchback  ...          Black
# 4                  0      GCC Specs      5            SUV  ...    Other Color
#
#    warranty                         address country   city  area_name  \
# ...

# %%
db2.head()
# Out:
#     price       brand      model           trim  kilometers  year  \
# 0  129900       Dodge        Ram  1500 SLT Crew       47566  2021
# 1  319900  Alfa Romeo    Stelvio   Quadrifoglio        8914  2020
# 2  149900        Audi         Q5         S-line       72205  2019
# 3   79900  Alfa Romeo  GIULIETTA         Veloce       49193  2021
# 4  154900         GAC        GS8             GL          30  2024
#
#    vehicle_age_years regional_specs  doors      body_type  ... interior_color  \
# 0                  3      GCC Specs      4  Pick Up Truck  ...        Unknown
# 1                  4      GCC Specs      5            SUV  ...          Black
# 2                  5      GCC Specs      5            SUV  ...          Brown
# 3                  3      GCC Specs      4      Hatchback  ...          Black
# 4                  0      GCC Specs      5            SUV  ...    Other Color
#
#    warranty                         address country   city  area_name  \
# ...

# %% [markdown]
# # Data Cleaning

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9953 entries, 0 to 9952
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   price               9953 non-null   int64
#  1   brand               9953 non-null   object
#  2   model               9953 non-null   object
#  3   trim                9941 non-null   object
#  4   kilometers          9953 non-null   int64
#  5   year                9953 non-null   int64
#  6   vehicle_age_years   9953 non-null   int64
#  7   regional_specs      9953 non-null   object
#  8   doors               9953 non-null   int64
#  9   body_type           9953 non-null   object
#  10  fuel_type           9953 non-null   object
#  11  seating_capacity    9953 non-null   int64
#  12  transmission_type   9953 non-null   object
#  13  engine_capacity_cc  7992 non-null   object
#  14  horsepower          9495 non-null   object
# ...

# %%
pd.isnull(db).sum()
# Out:
# price                    0
# brand                    0
# model                    0
# trim                    12
# kilometers               0
# year                     0
# vehicle_age_years        0
# regional_specs           0
# doors                    0
# body_type                0
# fuel_type                0
# seating_capacity         0
# transmission_type        0
# engine_capacity_cc    1961
# horsepower             458
# no_of_cylinders          0
# exterior_color           0
# interior_color           0
# warranty                 0
# address                  0
# country                  0
# city                     0
# area_name              619
# location_name         5320
# latitude               373
# longitude              373
# seller_type              0
# dtype: int64

# %%
db.shape
# Out:
# (9953, 27)

# %%
db.drop(['location_name','latitude','longitude','area_name','trim'], axis = 1 , inplace = True)

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9953 entries, 0 to 9952
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   price               9953 non-null   int64
#  1   brand               9953 non-null   object
#  2   model               9953 non-null   object
#  3   kilometers          9953 non-null   int64
#  4   year                9953 non-null   int64
#  5   vehicle_age_years   9953 non-null   int64
#  6   regional_specs      9953 non-null   object
#  7   doors               9953 non-null   int64
#  8   body_type           9953 non-null   object
#  9   fuel_type           9953 non-null   object
#  10  seating_capacity    9953 non-null   int64
#  11  transmission_type   9953 non-null   object
#  12  engine_capacity_cc  7992 non-null   object
#  13  horsepower          9495 non-null   object
#  14  no_of_cylinders     9953 non-null   int64
# ...

# %%
db.rename(columns = {'year' : 'purchased_year'}, inplace = True)

# %% [markdown]
# # Explortary Data Analysis (EDA)

# %% [markdown]
# # Year

# %%
#No. of car sells in a year trend
sns.set(rc={'figure.figsize':(25,15)})
a = sns.countplot(x= 'purchased_year', data = db)

for bars in a.containers:
    a.bar_label(bars)

# Set labels and title
a.set_xlabel('Year of Purchase')
a.set_ylabel('Count')
a.set_title('Number of Purchases per Year')
# Out:
# Text(0.5, 1.0, 'Number of Purchases per Year')

# %%
#Last 20 Years total Sales 
a = db.groupby(['purchased_year'],as_index= False)['price'].sum().sort_values(by = 'price', ascending = False).head(20)
sns.set(rc={'figure.figsize':(20,10)})
b = sns.barplot(x = 'purchased_year', y ='price', data = a )

# Set labels and title
b.set_xlabel('Year of Purchase')
b.set_ylabel('Total Sales')
b.set_title('Total amount Sales per Year')
# Out:
# Text(0.5, 1.0, 'Total amount Sales per Year')

# %% [markdown]
# **From above graphs, we can say that 2023 was the best year in terms of sales and number of car sold.**

# %% [markdown]
# # Brand & Model

# %%
#top 10 brands by units sold
top_brands = db['brand'].value_counts().head(10).index

# Filter the DataFrame to include only the top 10 brands
db_filtered = db[db['brand'].isin(top_brands)]

# Set the figure size
sns.set(rc={'figure.figsize':(15, 5)})

# Plot the countplot
a = sns.countplot(x='brand', data=db_filtered)

# Add labels to the bars
for bars in a.containers:
    a.bar_label(bars)

# Set labels and title
a.set_xlabel('Brand')
a.set_ylabel('No. of cars sold')
a.set_title('Number of cars sold by top 10 brands')
# Out:
# Text(0.5, 1.0, 'Number of cars sold by top 10 brands')

# %%
#Top 10 highest selling car brands 
a = db.groupby(['brand'],as_index= False)['price'].sum().sort_values(by = 'price', ascending = False).head(10)
sns.set(rc={'figure.figsize':(20,10)})
a = sns.barplot(x = 'brand', y ='price', data = a )

# Set labels and title
a.set_xlabel('Brand')
a.set_ylabel('Total Sales')
a.set_title('Total Sales of cars based on Brand')
# Out:
# Text(0.5, 1.0, 'Total Sales of cars based on Brand')

# %%
#Top 10 highest selling car model 
b = db.groupby(['brand','model'],as_index= False)['price'].sum().sort_values(by = 'price', ascending = False).head(10)
sns.set(rc={'figure.figsize':(20,10)})
a = sns.barplot(x = 'brand', y ='price', data = b ,hue = 'model')

# Set labels and title
a.set_xlabel('Brand')
a.set_ylabel('Amount of Sales')
a.set_title('Total amount of sales based on Brand')
# Out:
# Text(0.5, 1.0, 'Total amount of sales based on Brand')

# %% [markdown]
# **From the above graph, we can say that Mercedes Benz sold highest units folowed by BMW. Mercedes Benz also have highest sales.**

# %% [markdown]
# # Transmission Type

# %%
#No. of automatic and manual sells
sns.set(rc={'figure.figsize':(10,5)})
a = sns.countplot(x= 'transmission_type', data = db)

for bars in a.containers:
    a.bar_label(bars)

# Set labels and title
a.set_xlabel('Transmission Type')
a.set_ylabel('No. of cars sold')
a.set_title('Number of cars sold based on Transmission Type')
# Out:
# Text(0.5, 1.0, 'Number of cars sold based on Transmission Type')

# %%
#Top 10 highest selling car brands 
a = db.groupby(['transmission_type'],as_index= False)['price'].sum().sort_values(by = 'price', ascending = False).head(10)
sns.set(rc={'figure.figsize':(10,5)})
b = sns.barplot(x = 'transmission_type', y ='price', data = a )

# Set labels and title
b.set_xlabel('Transmission Type')
b.set_ylabel('Total Sales')
b.set_title('Total Sales based on Transmission Type')
# Out:
# Text(0.5, 1.0, 'Total Sales based on Transmission Type')

# %% [markdown]
# **From above graph, we can say that automatic transmission cars sells more in market.**

# %% [markdown]
# # Engine Capacity & Horse Power

# %%
#No. of automatic and manual sells
sns.set(rc={'figure.figsize':(15,5)})
a = sns.countplot(x= 'engine_capacity_cc', data = db)

for bars in a.containers:
    a.bar_label(bars)

# Set labels and title
a.set_xlabel('Engine Capacity CC')
a.set_ylabel('No. of cars sold')
a.set_title('Number of cars sold based on Engine Capacity CC')
# Out:
# Text(0.5, 1.0, 'Number of cars sold based on Engine Capacity CC')

# %%
a = db.groupby(['engine_capacity_cc'],as_index= False)['price'].sum().sort_values(by = 'price', ascending = False).head(7)
sns.set(rc={'figure.figsize':(20,5)})
b = sns.barplot(x = 'engine_capacity_cc', y ='price', data = a )

# Set labels and title
b.set_xlabel('Engine Capacity CC')
b.set_ylabel('Total Sales')
b.set_title('Total Sales based on Engine Capacity CC')
# Out:
# Text(0.5, 1.0, 'Total Sales based on Engine Capacity CC')

# %%
#No. of automatic and manual sells
sns.set(rc={'figure.figsize':(15,5)})
a = sns.countplot(x= 'horsepower', data = db)

for bars in a.containers:
    a.bar_label(bars)

# Set labels and title
a.set_xlabel('Horsepower')
a.set_ylabel('No. of cars sold')
a.set_title('Number of cars sold based on Horsepower')
# Out:
# Text(0.5, 1.0, 'Number of cars sold based on Horsepower')

# %%
a = db.groupby(['horsepower'],as_index= False)['price'].sum().sort_values(by = 'price', ascending = False).head(7)
sns.set(rc={'figure.figsize':(20,5)})
b = sns.barplot(x = 'horsepower', y ='price', data = a )

# Set labels and title
b.set_xlabel('Horsepower')
b.set_ylabel('Total Sales')
b.set_title('Total Sales based on Horsepower')
# Out:
# Text(0.5, 1.0, 'Total Sales based on Horsepower')

# %%
a = db.groupby(['horsepower', 'engine_capacity_cc'],as_index= False)['price'].sum().sort_values(by = 'price', ascending = False).head(20)
sns.set(rc={'figure.figsize':(20,5)})
b = sns.barplot(x = 'horsepower', y ='price', data = a, hue = 'engine_capacity_cc' )

# Set labels and title
b.set_xlabel('Horsepower')
b.set_ylabel('Total Sales')
b.set_title('Total Sales based on Horsepower and Engine Capacity CC')
# Out:
# Text(0.5, 1.0, 'Total Sales based on Horsepower and Engine Capacity CC')

# %% [markdown]
# **From above details, we can say 500-599 HP with 4000+ cc engine cars are prefer most.**

# %% [markdown]
# # Seating

# %%
#No. of cars sells on basis of doors
sns.set(rc={'figure.figsize':(15,5)})
a = sns.countplot(x= 'seating_capacity', data = db)

for bars in a.containers:
    a.bar_label(bars)

# Set labels and title
a.set_xlabel('No. of seats')
a.set_ylabel('No. of cars sold')
a.set_title('Number of cars sold based on No. of seats')
# Out:
# Text(0.5, 1.0, 'Number of cars sold based on No. of seats')

# %% [markdown]
# **From here, we can say people loves to buy car with 5 seats.**

# %% [markdown]
# # Colors

# %%
#No. of car sales on basis of exterior_color
sns.set(rc={'figure.figsize':(15,5)})
a = sns.countplot(x= 'exterior_color', data = db)

for bars in a.containers:
    a.bar_label(bars)

# Set labels and title
a.set_xlabel('Exterior Color')
a.set_ylabel('No. of cars sold')
a.set_title('Number of cars sold by Exterior Color')

# %%
#No. of car sales on basis of interior_color
sns.set(rc={'figure.figsize':(15,5)})
a = sns.countplot(x= 'interior_color', data = db)

for bars in a.containers:
    a.bar_label(bars)

# Set labels and title
a.set_xlabel('Interior Color')
a.set_ylabel('No. of cars sold')
a.set_title('Number of cars sold by Interior Color')

# %% [markdown]
# **From the above details, we can say that people loves black for interiors and white for exteriors.**

# %% [markdown]
# # Country and City

# %%
# Total Sales in different cities
sns.set(rc={'figure.figsize':(15,5)})
a = db.groupby(['city'],as_index= False)['price'].sum().sort_values(by = 'price', ascending = False)
b = sns.barplot(x = 'city', y ='price', data = a )

b.set_xlabel('City')
b.set_ylabel('Total sales Amount')
b.set_title('Total Sales in different cities')

# %%
#Number of Purchases by Cities
sns.set(rc={'figure.figsize':(10,5)})
a = sns.countplot(x= 'city', data = db)

for bars in a.containers:
    a.bar_label(bars)

# Set labels and title
a.set_xlabel('City')
a.set_ylabel('Count')
a.set_title('Number of Purchases by Cities')

# %% [markdown]
# **From above graphs, we can say that highest number of car and the sales amount were done recorded in Dubai, Abu Dhabi and Sharjah.**

# %% [markdown]
# # Seller Type

# %%
# Total Sales by different sellers
sns.set(rc={'figure.figsize':(15,5)})
a = db.groupby(['seller_type'],as_index= False)['price'].sum().sort_values(by = 'price', ascending = False)
b = sns.barplot(x = 'seller_type', y ='price', data = a )

b.set_xlabel('Seller Type')
b.set_ylabel('Total sales Amount')
b.set_title('Total Sales by different sellers')

# %%
#Number of cars sold by different sellers
sns.set(rc={'figure.figsize':(10,5)})
a = sns.countplot(x= 'seller_type', data = db)

for bars in a.containers:
    a.bar_label(bars)

# Set labels and title
a.set_xlabel('Seller Type')
a.set_ylabel('No. of cars sold')
a.set_title('Number of cars sold by different sellers')

# %% [markdown]
# **From above graphs, we can say that highest number of car and the sales amount were done by Dealer, Owner and Dealership/Certified Pre-Owned.**

# %% [markdown]
# # Conclusion

# %%
#Points:
#From above graphs, we can say that 2023 was the best year in terms of sales and number of car sold.
#From the above graph, we can say that Mercedes Benz sold highest units folowed by BMW. Mercedes Benz also have highest sales.
#From above graph, we can say that automatic transmission cars sells more in market.
#From above details, we can say 500-599 HP with 4000+ cc engine cars are prefer most.
#From here, we can say people loves to buy car with 5 doors.
#From above graphs, we can say that highest number of car and the sales amount were done recorded in Dubai, Abu Dhabi and Sharjah.
#From above graphs, we can say that highest number of car and the sales amount were done by Dealer, Owner and Dealership/Certified Pre-Owned.
#From the above details, we can say that people loves black for interiors and white for exteriors.

# %% [markdown]
# **The best year for the sales was 2023. People buys Mercedes Benz cars most with automatic transmission. They prefer them to be 5 seats with white on outside and black in inside colors. 500-599 HP with 4000+ cc engine cars are prefer most.**

# %% [markdown]
# **Highest number of buyers are from Dubai, Abu Dhabi and Sharjah were dealer sells most of the cars.**
